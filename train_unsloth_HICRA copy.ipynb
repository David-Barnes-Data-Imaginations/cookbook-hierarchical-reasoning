# %% [markdown]
# # Unsloth GRPO Training for Hierarchical Reasoning
#
# This notebook uses Unsloth's optimized kernels with TRL's GRPOTrainer for stable training.
#
# **Key features:**
# - ~50% less VRAM usage than standard transformers
# - vLLM fast inference for generation
# - HICRA-inspired reward functions for reasoning

# %%
# Cell 1: Environment Setup
import os
os.environ["UNSLOTH_VLLM_STANDBY"] = "1"  # Extra 30% context lengths
os.environ["fix_mistral_regex"] = "True"
# os.environ["OMP_NUM_THREADS"] = "1"

# Install dependencies (run this if not already installed)
# !pip install unsloth vllm
# !pip install transformers==4.56.2
# !pip install --no-deps trl==0.22.2

# %%
# Cell 2: HuggingFace Login
import os
from huggingface_hub import login
from dotenv import load_dotenv

load_dotenv()
hf_token = os.getenv('HF_TOKEN')

if hf_token:
    login(token=hf_token)
    print("✅ Logged in with HF_TOKEN")
else:
    login()
    print("✅ Logged in interactively")
# Out:
# ✅ Logged in with HF_TOKEN

# %%
from unsloth import FastLanguageModel
import torch
# Configuration
max_seq_length = 1024  # Can increase for longer reasoning traces
lora_rank = 32  # Larger rank = smarter, but slower
print("⏳ Loading model with Unsloth...")
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name="unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit",
    max_seq_length=max_seq_length,
    load_in_4bit=True,
    fast_inference=False,  # Disabled - requires CUDA toolkit for vLLM
)
print("🔗 Attaching LoRA adapters...")
model = FastLanguageModel.get_peft_model(
    model,
    r=lora_rank,
    target_modules=[
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj",
    ],
    lora_alpha=lora_rank,
    use_gradient_checkpointing="unsloth",  # Optimized gradient checkpointing
    random_state=3407,
)
print("✅ Model loaded successfully!")
# Out:
# ⏳ Loading model with Unsloth...
# ==((====))==  Unsloth 2025.12.8: Fast Llama patching. Transformers: 4.57.3. vLLM: 0.13.0.
#    \\   /|    NVIDIA GeForce RTX 4070 SUPER. Num GPUs = 1. Max memory: 11.594 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.9.0+cu128. CUDA: 8.9. CUDA Toolkit: 12.8. Triton: 3.5.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.33.post1. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# 🔗 Attaching LoRA adapters...
# Unsloth 2025.12.8 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.
# ✅ Model loaded successfully!

# %% [markdown]
# Tuning Tips:
# - If you're getting OOM: Lower NEMOTRON_SAMPLE_SIZE to 1000-2000
# - If generations are too long: Lower MAX_ANSWER_TOKENS to 400
# - If you want more data: Increase NEMOTRON_SAMPLE_SIZE to 5000+
# The filtering keeps ~60-70% of examples typically, so 3000 samples → ~2000 usable examples mixed with your 729 HICRA examples.

# %%
# Cell 4: Load and Combine Datasets
from datasets import load_dataset, Dataset
import json

# === Configuration ===
MAX_PROMPT_TOKENS = 400    # Filter out prompts longer than this
MAX_ANSWER_TOKENS = 600    # Filter out answers longer than this  
NEMOTRON_SAMPLE_SIZE = 3000  # How many Nemotron examples to use

# System prompt for reasoning format
SYSTEM_PROMPT = """
You are a mathematical reasoning assistant. Think through problems step by step.
Respond in the following format:
<think>
...
</think>
<answer>
...
</answer>
"""

def format_prompt(example):
    """Format dataset for GRPO training with chat template."""
    return {
        'prompt': [
            {'role': 'system', 'content': SYSTEM_PROMPT.strip()},
            {'role': 'user', 'content': example['prompt']}
        ],
        'answer': str(example['answer'])
    }

def format_nemotron(example):
    """Convert Nemotron format to our format."""
    messages = example.get('messages', [])
    
    # Extract user prompt and assistant answer
    user_content = ""
    assistant_content = ""
    
    for msg in messages:
        if msg['role'] == 'user':
            user_content = msg['content']
        elif msg['role'] == 'assistant':
            assistant_content = msg['content']
    
    # Get expected answer (fallback to assistant content if not available)
    expected = example.get('expected_answer', '')
    if not expected:
        # Try to extract from assistant's <answer> tags if present
        if '<answer>' in assistant_content and '</answer>' in assistant_content:
            expected = assistant_content.split('<answer>')[-1].split('</answer>')[0].strip()
        else:
            expected = assistant_content[-200:] if len(assistant_content) > 200 else assistant_content
    
    return {
        'prompt': user_content,
        'answer': str(expected)
    }

def estimate_tokens(text):
    """Rough token estimate (1 token ≈ 4 chars for English)."""
    return len(str(text)) // 4

def filter_by_length(example):
    """Filter out examples that are too long."""
    prompt_tokens = estimate_tokens(example['prompt'])
    answer_tokens = estimate_tokens(example['answer'])
    return prompt_tokens <= MAX_PROMPT_TOKENS and answer_tokens <= MAX_ANSWER_TOKENS

# === 1. Load Your HICRA Synthetic Data ===
print("📂 Loading HICRA dataset...")
my_dataset = load_dataset(
    "json", 
    data_files="reasoning_dataset_v2_train.json", 
    split="train"
)
print(f"   ✅ Loaded {len(my_dataset)} HICRA examples")

# === 2. Load Nemotron Math Data (Streaming) ===
print(f"🌊 Streaming {NEMOTRON_SAMPLE_SIZE} Nemotron math examples...")
try:
    nemotron_stream = load_dataset(
        "nvidia/Nemotron-Post-Training-Dataset-v1", 
        split="math", 
        streaming=True
    )
    
    # Take a sample and convert to list
    nemotron_list = []
    for i, example in enumerate(nemotron_stream):
        if i >= NEMOTRON_SAMPLE_SIZE:
            break
        formatted = format_nemotron(example)
        # Only keep if it's not too long
        if filter_by_length(formatted):
            nemotron_list.append(formatted)
        
        if (i + 1) % 500 == 0:
            print(f"   Processed {i + 1} examples, kept {len(nemotron_list)}...")
    
    nemotron_dataset = Dataset.from_list(nemotron_list)
    print(f"   ✅ Loaded {len(nemotron_dataset)} Nemotron examples (after length filter)")
    
except Exception as e:
    print(f"   ⚠️ Could not load Nemotron: {e}")
    print("   Continuing with HICRA data only...")
    nemotron_dataset = None

# === 3. Combine Datasets ===
print("🔀 Combining datasets...")

# Filter HICRA by length too
my_dataset_filtered = my_dataset.filter(filter_by_length)
print(f"   HICRA after filter: {len(my_dataset_filtered)} examples")

if nemotron_dataset and len(nemotron_dataset) > 0:
    from datasets import concatenate_datasets
    
    # Make sure both have the same columns
    combined_dataset = concatenate_datasets([my_dataset_filtered, nemotron_dataset])
    print(f"   ✅ Combined dataset: {len(combined_dataset)} examples")
else:
    combined_dataset = my_dataset_filtered
    print(f"   ✅ Using HICRA only: {len(combined_dataset)} examples")

# === 4. Format for GRPO Training ===
print("📝 Formatting for GRPO...")
dataset_train = combined_dataset.map(format_prompt)

# Shuffle to mix the datasets
dataset_train = dataset_train.shuffle(seed=42)

# === 5. Load Test Set (HICRA only) ===
dataset_test = load_dataset(
    "json", 
    data_files="reasoning_dataset_v2_test.json", 
    split="train"
).map(format_prompt)

print(f"\n✅ Final Training Set: {len(dataset_train)} examples")
print(f"✅ Test Set: {len(dataset_test)} examples")
print(f"\nSample prompt format:")
print(dataset_train[0]['prompt'])
# Out:
# 📂 Loading HICRA dataset...
#    ✅ Loaded 729 HICRA examples
# 🌊 Streaming 3000 Nemotron math examples...
#    Processed 500 examples, kept 498...
#    Processed 1000 examples, kept 998...
#    Processed 1500 examples, kept 1498...
#    Processed 2000 examples, kept 1998...
#    Processed 2500 examples, kept 2498...
#    Processed 3000 examples, kept 2997...
#    ✅ Loaded 2997 Nemotron examples (after length filter)
# 🔀 Combining datasets...
#    HICRA after filter: 729 examples
#    ✅ Combined dataset: 3726 examples
# 📝 Formatting for GRPO...
#
# ✅ Final Training Set: 3726 examples
# ✅ Test Set: 36 examples
#
# Sample prompt format:
# [{'content': 'You are a mathematical reasoning assistant. Think through problems step by step.\nRespond in the following format:\n<think>\n...\n</think>\n<answer>\n...\n</answer>', 'role': 'system'}, {'content': 'Evaluate the integral \\(\\int_0^{2\\pi} \\sqrt{\\sin^2(t) \\cos^2(t)} \\, dt\\).', 'role': 'user'}]

# %%
# Cell 5: Reward Functions
import re

# Strategic reasoning phrases (from HICRA paper)
STRATEGIC_GRAMS = [
    "first i need to", "let's look at", "alternatively", "wait",
    "but i'm not sure", "let's see if", "notice that",
    "the final answer is", "let's assume", "we can conclude",
    "implies that", "to solve this", "break it down",
    "suppose that", "checking the", "recall that",
    "step 1", "step 2", "therefore", "thus"
]

def extract_xml_answer(text: str) -> str:
    """Extract answer from <answer> tags."""
    if "<answer>" not in text:
        return text.strip()
    answer = text.split("<answer>")[-1]
    answer = answer.split("</answer>")[0]
    return answer.strip()

def correctness_reward_func(prompts, completions, answer, **kwargs) -> list[float]:
    """
    Check if the model's answer matches the expected answer.
    Returns 2.0 for correct, 0.0 for incorrect.
    """
    responses = [completion[0]['content'] for completion in completions]
    extracted = [extract_xml_answer(r) for r in responses]
    
    # Debug output (first item only)
    q = prompts[0][-1]['content'][:100]  # First 100 chars of question
    print(f"---\nQ: {q}...\nExpected: {answer[0]}\nExtracted: {extracted[0][:50]}...")
    
    rewards = []
    for ext, ans in zip(extracted, answer):
        # Check if answer appears in extracted text
        if str(ans).strip() in ext:
            rewards.append(2.0)
        else:
            rewards.append(0.0)
    return rewards

def reasoning_reward_func(completions, **kwargs) -> list[float]:
    """
    HICRA-inspired reward for reasoning structure.
    Gives bonus for using strategic reasoning phrases.
    """
    responses = [completion[0]['content'] for completion in completions]
    rewards = []
    
    for response in responses:
        score = 0.0
        response_lower = response.lower()
        
        # Check for strategic grams
        for gram in STRATEGIC_GRAMS:
            if gram in response_lower:
                score += 0.05
        
        # Bonus for using reasoning tags
        if "<think>" in response and "</think>" in response:
            score += 0.2
        if "<answer>" in response and "</answer>" in response:
            score += 0.1
        
        # Cap the reward
        rewards.append(min(score, 0.5))
    
    return rewards

def format_reward_func(completions, **kwargs) -> list[float]:
    """Reward for correct XML format."""
    pattern = r"<think>.*?</think>\s*<answer>.*?</answer>"
    responses = [completion[0]['content'] for completion in completions]
    return [0.5 if re.search(pattern, r, re.DOTALL) else 0.0 for r in responses]

print("✅ Reward functions defined")
# Out:
# ✅ Reward functions defined

# %% [markdown]
# ### Chat Template (Save for Base models)

# %% [markdown]
# ```
# # Set Llama 3 chat template (required for GRPO with conversational data)
# tokenizer.chat_template = """{% for message in messages %}{% if message['role'] == 'system' %}<|begin_of_text|><|start_header_id|>system<|end_header_id|>
# {{ message['content'] }}<|eot_id|>{% elif message['role'] == 'user' %}<|start_header_id|>user<|end_header_id|}
# {{ message['content'] }}<|eot_id|>{% elif message['role'] == 'assistant' %}<|start_header_id|>assistant<|end_header_id|>
# {{ message['content'] }}<|eot_id|>{% endif %}{% endfor %}{% if add_generation_prompt %}<|start_header_id|>assistant<|end_header_id|>
# {% endif %}"""
# print("✅ Chat template set!")
# ```

# %% [markdown]
# **Optional: Use More GPU**
# You could also try:
#
# - `num_generations=6` (more diverse rollouts per step)
# - Or increase `max_seq_length=1280` in cell 3 if Nemotron answers are very long

# %%
# Cell 7 (updated)
from trl import GRPOConfig, GRPOTrainer

# Adjusted: Give more tokens to completions
max_prompt_length = 384     # Up from 256 - plenty for most math questions
max_completion_length = 640 # 1024 - 384 = 640 tokens for reasoning

training_args = GRPOConfig(
    # Optimization
    learning_rate=5e-6,
    adam_beta1=0.9,
    adam_beta2=0.99,
    weight_decay=0.1,
    warmup_ratio=0.1,
    lr_scheduler_type="cosine",
    optim="paged_adamw_8bit",
    
    # 8 generations gives the model much better variance to learn from.
    num_generations=8, 
    
    # Keep batch size small to fit the 8 generations in memory
    per_device_train_batch_size=1,
    gradient_accumulation_steps=8, # 1 * 8 = 8 samples per step (Standard)
    
    # LENGTH: Give it room to think!
    # 1B models often ramble. 640 is good, but 768 is safer if VRAM allows.
    max_completion_length=768,
    
    # STEPS: 1B needs repetition.
    max_steps=2500,
)

print(f"✅ Training configuration set")
print(f"   Prompt: {max_prompt_length} tokens, Completion: {max_completion_length} tokens")
# Out:
# ✅ Training configuration set
#    Prompt: 384 tokens, Completion: 640 tokens

# %%
# Cell 7: Initialize Trainer
print("🚀 Initializing GRPO Trainer...")

trainer = GRPOTrainer(
    model=model,
    processing_class=tokenizer,
    reward_funcs=[
        correctness_reward_func,
        reasoning_reward_func,
        format_reward_func,
    ],
    args=training_args,
    train_dataset=dataset_train,
)

print("✅ Trainer initialized!")
# Out:
# 🚀 Initializing GRPO Trainer...
# ✅ Trainer initialized!

# %% [markdown]
# Current settings `nvidia-smi` says: `6861MiB /  12282MiB`

# %%
# Cell 8: Run Training!
print("🏋️ Starting training...")
print("Note: First ~100 steps may show 0 reward. Be patient!")
print("="*50)

trainer_stats = trainer.train()

print("="*50)
print("✅ Training complete!")
# Out:
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# 🏋️ Starting training...
# Note: First ~100 steps may show 0 reward. Be patient!
# ==================================================
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 3,726 | Num Epochs = 1 | Total steps = 2,500
# O^O/ \_/ \    Batch size per device = 1 | Gradient accumulation steps = 8
# \        /    Data Parallel GPUs = 1 | Total batch size (1 x 8 x 1) = 8
#  "-____-"     Trainable parameters = 83,886,080 of 8,114,147,328 (1.03% trained)
# Unsloth: Will smartly offload gradients to save VRAM!
# ---
# Q: Solve the system of linear equations:
# \[ 3x - 5y + 4z = 5 \]
# \[ 7x + 2y - 3z = 2 \]
# \[ 4x + 3y - 7z ...
# Expected: 3) = 7 + 4 - 9 = 2\), which holds.
# - For \(4x + 3y - 7z = -11\): \(4(1) + 3(2) - 7(3) = 4 + 6 - 21 = -11\), which holds.
#
# The solution is presented as an ordered triple \((x, y, z)\).
#
# \boxed{(1,2,3)}
# Extracted: <think>
# To solve the system of linear equations, w...
#     <div>
#
#       <progress value='95' max='2500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  95/2500 2:19:55 < 60:18:40, 0.01 it/s, Epoch 0.03/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completions / mean_length</th>
#       <th>completions / min_length</th>
#       <th>completions / max_length</th>
#       <th>completions / clipped_ratio</th>
#       <th>completions / mean_terminated_length</th>
#       <th>completions / min_terminated_length</th>
#       <th>completions / max_terminated_length</th>
#       <th>sampling / sampling_logp_difference / mean</th>
#       <th>sampling / sampling_logp_difference / max</th>
#       <th>sampling / importance_sampling_ratio / min</th>
#       <th>sampling / importance_sampling_ratio / mean</th>
#       <th>sampling / importance_sampling_ratio / max</th>
#       <th>kl</th>
#       <th>rewards / correctness_reward_func / mean</th>
#       <th>rewards / correctness_reward_func / std</th>
#       <th>rewards / reasoning_reward_func / mean</th>
#       <th>rewards / reasoning_reward_func / std</th>
#       <th>rewards / format_reward_func / mean</th>
#       <th>rewards / format_reward_func / std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>0.037500</td>
#       <td>0.035355</td>
#       <td>729.250000</td>
#       <td>458.000000</td>
#       <td>768.000000</td>
#       <td>0.875000</td>
#       <td>458.000000</td>
#       <td>458.000000</td>
#       <td>458.000000</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.037500</td>
#       <td>0.035355</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>0.025000</td>
#       <td>0.037796</td>
#       <td>651.250000</td>
#       <td>232.000000</td>
#       <td>768.000000</td>
#       <td>0.750000</td>
#       <td>301.000000</td>
#       <td>232.000000</td>
#       <td>370.000000</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.025000</td>
#       <td>0.037796</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>0.262500</td>
#       <td>0.366206</td>
#       <td>662.375000</td>
#       <td>338.000000</td>
#       <td>768.000000</td>
#       <td>0.750000</td>
#       <td>345.500000</td>
#       <td>338.000000</td>
#       <td>353.000000</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>0.000260</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.137500</td>
#       <td>0.164208</td>
#       <td>0.125000</td>
#       <td>0.231455</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#       <td>0.025000</td>
#       <td>0.037796</td>
#       <td>762.250000</td>
#       <td>722.000000</td>
#       <td>768.000000</td>
#       <td>0.875000</td>
#       <td>722.000000</td>
#       <td>722.000000</td>
#       <td>722.000000</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>0.000415</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.025000</td>
#       <td>0.037796</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>0.081250</td>
#       <td>0.099777</td>
#       <td>703.375000</td>
#       <td>372.000000</td>
#       <td>768.000000</td>
#       <td>0.750000</td>
#       <td>509.500000</td>
#       <td>372.000000</td>
#       <td>647.000000</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>0.000502</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.081250</td>
#       <td>0.099777</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000000</td>
#       <td>0.162500</td>
#       <td>0.298508</td>
#       <td>617.875000</td>
#       <td>297.000000</td>
#       <td>768.000000</td>
#       <td>0.500000</td>
#       <td>467.750000</td>
#       <td>297.000000</td>
#       <td>726.000000</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>0.000507</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.100000</td>
#       <td>0.122474</td>
#       <td>0.062500</td>
#       <td>0.176777</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>0.087500</td>
#       <td>0.083452</td>
#       <td>662.875000</td>
#       <td>367.000000</td>
#       <td>768.000000</td>
#       <td>0.500000</td>
#       <td>557.750000</td>
#       <td>367.000000</td>
#       <td>728.000000</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>0.000389</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.087500</td>
#       <td>0.083452</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>0.062500</td>
#       <td>0.058248</td>
#       <td>768.000000</td>
#       <td>768.000000</td>
#       <td>768.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>0.000398</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.062500</td>
#       <td>0.058248</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>-0.000000</td>
#       <td>2.100000</td>
#       <td>0.075593</td>
#       <td>724.875000</td>
#       <td>423.000000</td>
#       <td>768.000000</td>
#       <td>0.875000</td>
#       <td>423.000000</td>
#       <td>423.000000</td>
#       <td>423.000000</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>0.000466</td>
#       <td>2.000000</td>
#       <td>0.000000</td>
#       <td>0.100000</td>
#       <td>0.075593</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000000</td>
#       <td>0.143750</td>
#       <td>0.072887</td>
#       <td>642.000000</td>
#       <td>328.000000</td>
#       <td>768.000000</td>
#       <td>0.625000</td>
#       <td>432.000000</td>
#       <td>328.000000</td>
#       <td>618.000000</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>0.000455</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.143750</td>
#       <td>0.072887</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.000000</td>
#       <td>0.137500</td>
#       <td>0.269590</td>
#       <td>586.500000</td>
#       <td>210.000000</td>
#       <td>768.000000</td>
#       <td>0.500000</td>
#       <td>405.000000</td>
#       <td>210.000000</td>
#       <td>659.000000</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>0.000493</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.075000</td>
#       <td>0.096362</td>
#       <td>0.062500</td>
#       <td>0.176777</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.000000</td>
#       <td>0.068750</td>
#       <td>0.084251</td>
#       <td>705.625000</td>
#       <td>529.000000</td>
#       <td>768.000000</td>
#       <td>0.625000</td>
#       <td>601.666687</td>
#       <td>529.000000</td>
#       <td>717.000000</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>0.000404</td>
#       <td>0.000000</td>
#       <td>
# ---
# Q: Solve the given equations: $\sin (a+x)+\sin x=\cos \frac{a}{2}$....
# Expected: that case.
#
# The solution for \(x\) in terms of \(a\) is:
# \[
# \boxed{x = -\dfrac{a}{2} + \dfrac{\pi}{6} + 2k\pi \quad \text{or} \quad x = -\dfrac{a}{2} + \dfrac{5\pi}{6} + 2k\pi, \quad k \in \mathbb{Z}}
# Extracted: <think>
# We start by using the angle addition formu...
# ---
# Q: In a cube with edge a through the midpoints of two parallel edges not lying in one face a straight l...
# Expected: sidering the symmetry and using integration or geometric properties. The expression accounts for the specific rotation axis and the cube's dimensions.
#
# \boxed{\dfrac{a^{3}}{3}\left(3\sqrt{2}-2\right)}
# Extracted: <think>
# To begin with, let's understand the proble...
# ---
# Q: A quality control manager oversees three production lines that produce defective items at rates of 2...
# Expected: 1182
# Extracted: <think>
# Let's start by considering the minimum pro...
# ---
# Q: Triangle ABC has sides AC = 3, BC = 5, and AB = 7. A circle is drawn internally tangent to the circu...
# Expected: {4}\).
#
# Verification confirms that the circle satisfies the conditions of being internally tangent to the circumcircle at C and tangent to AB at D, with all distances consistent.
#
# \boxed{\dfrac{7}{4}}
# Extracted: <think>
# Let's denote the center of the circumcircl...
# ---
# Q: Let \(ABCD\) be a trapezoid with \(BC \parallel AD\), \(\angle ADC = 57^\circ\), \(\angle DAB = 33^\...
# Expected: irc\), and \(\theta = 114^\circ\).
#
# The length \(MN \approx 5\), and in exact terms, for the degenerate case, \(MN = 5\).
#
# Thus, \(\angle MNA = 114^\circ\) and \(MN = 5\).
#
# \boxed{114^\circ} \boxed{5}
# Extracted: <think>
#
# To solve this problem, we can first use t...
# ---
# Q: For the differential equation \( x^2 y'' + \alpha x y' + (x + 3)y = 0 \), find all values of \(\alph...
# Expected: zero when the real parts are positive. Thus, the condition \( \alpha < 1 \) ensures all solutions approach zero as \( x \to 0 \).
#
# The solution set is all real numbers less than 1.
#
# \boxed{\alpha < 1}
# Extracted: <think>
#
# To find the values of α for which all sol...
# ---
# Q: A long thin strip of paper is 1024 units in length, 1 unit in width, and is divided into 1024 unit s...
# Expected:  in decimal.
#
# Thus, the square that was originally the 942nd is at height 727 in the stack (0-based, from the bottom). The number of squares below it is equal to its height, which is 727.
#
# \boxed{727}
# Extracted: <think>
# To find the answer, we need to determine t...
# ---
# Q: A circular table has 10 seats numbered 1 through 10 clockwise. Ten people with distinct heights sit ...
# Expected: 0
# Extracted: <think>
# To approach this problem, let's first cons...
# ---
# Q: An isosceles triangle \(ABC\) with \(AB = AC\) has an incircle of radius \(r\). The centroid \(M\) o...
# Expected: {6} = 6 \left(\frac{a\sqrt{6}}{6}\right) = 6r.
# \]
#
# Thus, the distance from vertex \(A\) to the point \(D\) (the intersection of the angle bisector of \(\angle BAC\) with \(BC\)) is \(6r\).
#
# \boxed{6r}
# Extracted: <think>
# To solve this problem, we can start by usi...
# ---
# Q: For a certain \( m \ge 2 \), let \( a \) and \( b \) be positive integers such that \( 2^a \in A_m \...
# Expected: both conditions simultaneously, as smaller values of \(a\) or \(b\) do not satisfy the respective conditions.
#
# The relation between \(a_0\) and \(b_0\) is therefore \(a_0 = 2b_0\).
#
# \boxed{a_0 = 2b_0}
# Extracted: <think>
#
# Given that \( a \) and \( b \) are positi...
# ---
# Q: Find the value of the integral \(\int_{-1}^{1} \frac{\sin m}{1 - 2 \cos m + x^2} \, dx\) where \(\pi...
# Expected: nominator does not yield a constant, it is likely that the intended denominator is \(1 - 2x \cos m + x^2\). With this assumption, the integral evaluates to \(-\frac{\pi}{2}\).
#
# \boxed{-\dfrac{\pi}{2}}
# Extracted: <think>
# To solve this integral, we'll first make a...
# ---
# Q: For what values of \( n \in \mathbb{Z} \) is \( K_n = n^2 + 20n + 12 \) a perfect square?...
# Expected:
# - For \(n = 13\), \(K_n = 13^2 + 20(13) + 12 = 169 + 260 + 12 = 441 = 21^2\).
#
# No other integer values satisfy the condition.
#
# The solutions are listed in ascending order.
#
# \boxed{-33,\ -23,\ 3,\ 13}
# Extracted: <think>
#
# To find when \( K_n = n^2 + 20n + 12 \) i...
# ---
# Q: Let \( x, a, h \) be arbitrary real numbers such that \( x > 0, a \ge -1, h > 0 \) and let the seque...
# Expected: \(a = -1\)).
#
# The conditions and the sum cover all scenarios where the series converges under the given constraints \(x > 0\), \(a \geq -1\), and \(h > 0\).
#
# \boxed{\dfrac{x\left(a + h\right)}{h - 1}}
# Extracted: <think>
# To explore for which $h$ the infinite sum ...
# ---
# Q: A sports car is speeding at a constant 40 m/s in a straight line. It passes a stationary police car....
# Expected: 37.25 s
# Extracted: The sports car will be caught by the police car in...
# ---
# Q: Given $\frac{x^2 + y^2}{x^2 - y^2} + \frac{x^2 - y^2}{x^2 + y^2} = k$, find $\frac{x^8 + y^8}{x^8 - ...
# Expected: frac{1}{p^2}\right) + 6}{4\left(p + \frac{1}{p}\right)} = \frac{(k^2 - 2) + 6}{4k} = \frac{k^2 + 4}{4k}.
# \]
# Thus:
# \[
# \frac{x^8 + y^8}{x^8 - y^8} = \frac{k^2 + 4}{4k}.
# \]
#
# \boxed{\dfrac{k^{2} + 4}{4k}}
# Extracted: For the equation $\frac{x^2 + y^2}{x^2 - y^2} + \f...
# ---
# Q: In a complex logic puzzle, seven people are seated in a circle. Exactly one person is an impostor wh...
# Expected: Person 4
# Extracted: <think>
# Let's denote the 7 people as 1 to 7, and t...
# ---
# Q: A debtor has two debts: Debt A ($50,000 at 6% APR) and Debt B ($30,000 at 9% APR), both compounded m...
# Expected: 60951.72
# Extracted: <think>
#
# To solve this problem, we will first calc...
# ---
# Q: Find the number of inversions and the parity of the permutation 328945167....
# Expected:
#
# Counting these, there are 15 inversions.
#
# The parity of a permutation is determined by the parity of the number of inversions. Since 15 is odd, the parity is odd.
#
# \boxed{15 \text{ and } \text{odd}}
# Extracted: Total number of inversions: 35 (it was actually 35...
# ---
# Q: How many ordered triples of integers $(x, y, z)$ are there such that $|x|, |y|, |z| < 10$ and $$\arc...
# Expected: iples is \(3 + 6 + 6 + 6 = 21\).
#
# All triples satisfy \(|x|, |y|, |z| < 10\) and the sum of arctangents is \(\frac{\pi}{2}\), and there are no other solutions within the given constraints.
#
# \boxed{21}
# Extracted: <think>
# To tackle this problem, we need to use the...
# ---
# Q: Let $\Omega=[0,1] \times [0,1]$ and $P=dxdy$. Find the conditional expectation $E(x^2+y^2 | \sigma(x...
# Expected: uous over \([0, 2]\).
#
# Thus, the conditional expectation is \(\frac{2}{3} (x + y)^2 - \frac{2}{3} \max(x + y - 1, 0)\).
#
# \boxed{\dfrac{2}{3}\left(x+y\right)^{2}-\dfrac{2}{3}\max\left(x+y-1,\ 0\right)}
# Extracted: (think)
#
# To find the conditional expectation, we n...
# ---
# Q: Determine the values of \(a\) and \(b\) such that the polynomial \(ax^{17} + bx^{16} - 1\) is divisi...
# Expected: 1597\). Therefore:
# \[
# a = -987, \quad b = 1597.
# \]
# Verification confirms that with these values, \(a \phi^{17} + b \phi^{16} - 1 = 0\) and \(a \psi^{17} + b \psi^{16} - 1 = 0\).
#
# \boxed{(-987,\ 1597)}
# Extracted: <think>
# To solve this problem, we need to use the ...
# ---
# Q: Solve the system of equations $$\left\{\begin{array}{lll} (3x+y)^{x-y}=9,\medskip \\ \sqrt [x-y]{324...
# Expected: }, -\frac{3}{4} \right)\) and \(\left( -\frac{1}{4}, -\frac{9}{4} \right)\).
#
# \[
# \boxed{\left( \dfrac{5}{4},\ -\dfrac{3}{4} \right) \quad \text{and} \quad \left( -\dfrac{1}{4},\ -\dfrac{9}{4} \right)}
# Extracted: <think>
# To start, let's analyze what we have:
#
# 1. ...
# ---
# Q: Find $ \sqrt{53} \bmod{143} $....
# Expected: 9 \equiv -14 \pmod{143}\). The smallest positive solution is 14. Given that the problem asks for "the" answer and to box a single value, the principal and smallest positive solution is 14.
#
# \boxed{14}
# Extracted: $ \sqrt{53} \bmod{143} = 8 $...
# ---
# Q: Five logic students—Alice, Ben, Chloe, David, and Eve—each pick a different integer from 1 to 100. T...
# Expected: David
# Extracted: <think>
#
# To find the person who made the false sta...
# ---
# Q: How many prime numbers \( p \) satisfy the inequality \( \left| 2 + \log_{\frac{3}{p}}(3p^2) \right|...
# Expected:  1. Primes greater than or equal to 29 (e.g., \(p = 29\), \(| \frac{3}{1 - x} | \approx 1.452 < 1.5\)) do not satisfy the inequality.
#
# There are 8 prime numbers that satisfy the inequality.
#
# \boxed{8}
# Extracted: <think>
# To begin with, let's focus on the logarith...
# ---
# Q: If \( x + y^2 + z^3 = xyz \) and \( z = \gcd(x, y) \), find all pairs \((x, y)\)....
# Expected: hile \(5 \cdot 3 \cdot 1 = 15\).
#
# No other integer pairs satisfy the equation and the gcd condition.
#
# \boxed{(-1,\ -1)} \boxed{(-1,\ 0)} \boxed{(4,\ 2)} \boxed{(4,\ 6)} \boxed{(5,\ 2)} \boxed{(5,\ 3)}
# Extracted: \[ (0, 0), (1, i), (-1,0), (1, 0) \]...
# ---
# Q: Let \( C_1 \) and \( C_2 \) be externally tangent circles with radii 2 and 3, respectively. Let \( C...
# Expected: }, -5/\sqrt{5})\).
# - \(|O_1 - O_2| = \sqrt{(2/\sqrt{5})^2 + (11/\sqrt{5})^2} = \sqrt{4/5 + 121/5} = \sqrt{25} = 5\).
#
# All conditions are satisfied, and \(r = 8\) is the only valid solution.
#
# \boxed{8}
# Extracted: <think>
#
# We have circles \( C_1 \) and \( C_2 \) w...
# ---
# Q: A point $P$ is selected uniformly at random from the interior of a rectangular box with side lengths...
# Expected: 3
# Extracted: <think>
#
# To solve this problem, we can use the con...
# ---
# Q: On a $55 \times 55$ tile board, what is the least possible value of $n$ pieces such that, by moving ...
# Expected: with a downward move, or other adjacent positions, work. Thus, \(n = 2\) is sufficient.
#
# Since \(n = 1\) is insufficient and \(n = 2\) is achievable, the least possible value of \(n\) is 2.
#
# \boxed{2}
# Extracted: <think>
# To solve this problem, we need to determin...
# Unsloth: Input IDs of shape torch.Size([8, 1044]) with length 1044 > the model's max sequence length of 1024.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Unsloth: Input IDs of shape torch.Size([1, 1044]) with length 1044 > the model's max sequence length of 1024.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# ---
# Q: A search and rescue team is looking for a lost hiker in a region divided into four zones: A, B, C, a...
# Expected: 4.48
# Extracted: <think>
# To maximize the overall probability of fin...
# ---
# Q: $\frac{\left(85\frac{7}{30}-83\frac{5}{18}\right):2\frac{2}{3}}{0.04}$...
# Expected:
# \(\frac{11}{15} \div 0.04 = \frac{11}{15} \times 25 = \frac{11 \times 25}{15} = \frac{275}{15} = \frac{55}{3}\) (simplified by dividing by 5).
#
# The result is \(\frac{55}{3}\).
#
# \boxed{\dfrac{55}{3}}
# Extracted: <think>
# To solve this complex expression, let's br...
# ---
# Q: Determine whether the series \( x_1 + x_2 + \cdots \) is convergent or divergent, where \( x_n = |\s...
# Expected: \infty r^n. \]
# The first sum is finite, and the second sum is a convergent geometric series since \( r < 1 \). Therefore, the series \( \sum_{n=1}^\infty x_n \) converges.
#
# \boxed{\text{convergent}}
# Extracted: <think>
#
# To determine the convergence or divergenc...
# ---
# Q: The latitude and longitude of New Orleans is $30^\circ$ N and $90^\circ$ W. On the other side of the...
# Expected: frac{3\sqrt{3} - 4}{6} = \frac{\pi R (3\sqrt{3} - 4)}{6}
#   \]
#
# John travels farther by \(\frac{\pi R (3\sqrt{3} - 4)}{6}\), where \(R\) is the Earth's radius.
#
# \boxed{\dfrac{\pi R (3\sqrt{3} - 4)}{6}}
# Extracted: <think>
# We will compare the distances that John an...
# ---
# Q: A water tank is being filled and drained simultaneously. Water flows in at a rate of n² liters per h...
# Expected: 2000
# Extracted: <think>
#
# 1. To determine the smallest positive int...
# ---
# Q: Let \( A_0A_1 \ldots A_n \) be a regular polygon inscribed in a circle of radius 1. Define \( d_i = ...
# Expected: simplifies to \((F_{n+1})^2\).
#
# This result holds for \(n \geq 1\), corresponding to polygons with at least two vertices (e.g., a digon for \(n=1\), a triangle for \(n=2\), etc.).
#
# \boxed{(F_{n+1})^2}
# Extracted: $\prod_{i=1}^{n} (5 - d...
# ---
# Q: In a group of \( n \) people (\( n \geq 2 \)), each person randomly picks another person and throws ...
# Expected: e not hit), and for \(p = 1\) and \(n = 2\), it gives 0 (both are hit). Verification with small \(n\) (e.g., \(n = 2\) and \(n = 3\)) confirms the result.
#
# \boxed{n\left(1-\dfrac{p}{n-1}\right)^{n-1}}
# Extracted: <think>
#
# Let's consider a person \( A \) who is pi...
# ---
# Q: Let \(a, b, c, x, y, z\) be real numbers such that \(xyz \neq 0\) and \(a = \frac{by}{z} + \frac{cz}...
# Expected: n-zero for arbitrary \(x\), \(y\), \(z\), confirming that only the trivial solution exists.
#
# Therefore, \(a^3 + b^3 + c^3 = 0\) for all real numbers \(x\), \(y\), \(z\) with \(xyz \neq 0\).
#
# \boxed{0}
# Extracted: The calculations imply that $a + b + c = 0$. Subst...
# ---
# Q: Given the equation \( \pm x^2 = 5^{4s + 1}c^4 2^{2\alpha} - d^4 2^{2\beta} \) where \( c \) and \( d...
# Expected:  \(\beta\), \(c\), and \(d\) either violate the relative primality conditions, the coprimality to 5, or do not yield an integer solution for \(x\).
#
# Thus, the solution is \(x = \pm 1\).
#
# \boxed{\pm 1}
# Extracted: <think>
# We have the given equation:
# \[ \pm x^2 = 5...
# ---
# Q: A retirement fund has four investment tiers. Tier 1 has 40 accounts with $25,000 each at 4.5% compou...
# Expected: 90
# Extracted: <think>
# First, we need to find the value of each a...
# ---
# Q: Given a cyclic quadrilateral $ABCD$ inscribed in a circle with center $O$, where $\angle BAC < \angl...
# Expected: ons.
#
# The constraints and the strict inequality \(\angle BAC < \angle DCB\) ensure that the arcs are positive and less than \(180^\circ\), maintaining convexity.
#
# \boxed{60^\circ < \alpha < 120^\circ}
# Extracted: <think>
#
# Let's denote the points of intersection b...
# ---
# Q: Let \( n \) be a positive integer. If \( S \) is a nonempty set of positive integers, we say \( S \)...
# Expected: ), and there are 52 partitions of the set \(P\). Each partition generates a distinct 2310-complete set, and all such sets are nonempty. Therefore, there are 52 distinct 2310-complete sets.
#
# \boxed{52}
# Extracted: <think>
#
# We can find the prime factorization of 23...
# ---
# Q: Given $a \in (-1, 1)$ and $A \in M_n(\mathbb{R})$ such that $\det(A^4 - aA^3 - aA + I) = 0$, find th...
# Expected: ed under the interpretation that \(p(A) = 0\), the determinant is 1 when \(n\) is even.
#
# The condition for \(A\) to exist is that \(n\) is an even positive integer, and then \(\det A = 1\).
#
# \boxed{1}
# Extracted: <think>
#
# We are given that $\det(A^4 - aA^3 - aA +...
# ---
# Q: Given that triangle CAB is congruent to triangle EFD, with \( AC = x + y + z \), \( AB = z + 6 \), \...
# Expected:  \(10 > 6\)
# - \(6 + 7 > 3\) → \(13 > 3\)
#
# Compute \(x^2 + y^2 + z^2\):
# \((-2)^2 + 4^2 + 1^2 = 4 + 16 + 1 = 21\)
#
# Thus, the solution satisfies the congruence and side length conditions.
#
# \boxed{21}
# Extracted: <think>
#
# Since triangle CAB is congruent to triang...
# ---
# Q: Let \( T_{n} = \sum_{k=1}^{n-1}\frac{n}{n^2+kn+k^2} \). Determine whether \( T_{n} < \frac{\pi}{3\sq...
# Expected: 1}{3} > 0 \), \( T_n \) is strictly less than the integral.
#
# Thus, for all \( n \geq 1 \) (with \( T_1 = 0 \) as an empty sum), \( T_n < \frac{\pi}{3\sqrt{3}} \).
#
# \boxed{T_n < \dfrac{\pi}{3\sqrt{3}}}
# Extracted: <think>
# To determine whether \( T_{n} < \frac{\pi}...
# ---
# Q: Given the curve \( f(x) = x^3 \) and the point \( M(X_0, Y_0) \) from Problem 1, find the equation o...
# Expected: the equation reduces to \(x = 0\), which is the vertical normal line at the origin.
#
# Thus, the equation of the normal line is:
# \[
# (x - X_0) + 3X_0^2 (y - Y_0) = 0
# \]
#
# \boxed{(x-X_0)+3X_0^{2}(y-Y_0)=0}
# Extracted: <think>
# To find the equation of the normal line to...
# ---
# Q: A conference organizer has 15 speakers and needs to form discussion panels over 3 time slots. Each p...
# Expected: 6
# Extracted: 13 panels can be scheduled at maximum....
# ---
# Q: Solve the equation $\tan(x) + \tan(2x) = \tan(3x)$....
# Expected: , as cases where \(S \neq 0\) lead to contradictions or undefined expressions.
#
# Thus, the solution set is all \(x = \frac{n\pi}{3}\) for integers \(n\).
#
# \boxed{x = \dfrac{n\pi}{3},\ n \in \mathbb{Z}}
# Extracted: We divide the left term by cos(x) to obtain:
# $\fra...
# ---
# Q: In a regular quadrangular pyramid the lateral edge of length $m$ is inclined to the plane of the bas...
# Expected: mes (m \sin \alpha) = \frac{2}{3} m^3 \sin \alpha \cos^2 \alpha
# \]
#
# Thus, the volume of the pyramid is \(\frac{2}{3} m^3 \sin \alpha \cos^2 \alpha\).
#
# \boxed{\dfrac{2}{3}m^{3}\sin\alpha\cos^{2}\alpha}
# Extracted: In this general problem we must take awhile to thi...
# ---
# Q: A t-shirt vendor sells 30 t-shirts a day for $10 each. For each $1 increase in price, she sells 4 fe...
# Expected: 4 \times 8.75 = 70 - 35 = 35\), and the revenue is \(8.75 \times 35 = 306.25\), which is higher than at adjacent prices (e.g., $9.00 with revenue $306.00 or $10.00 with revenue $300.00).
#
# \boxed{8.75}
# Extracted: The vendor can increase her profit by selling the ...
# ---
# Q: How many regular polygons can be formed using the vertices of a 2010-sided regular polygon?...
# Expected: 67} = \frac{1005 \times 498}{67}.
# \]
#
# Since \(1005 = 15 \times 67\):
# \[
# \frac{15 \times 67 \times 498}{67} = 15 \times 498 = 7470.
# \]
#
# Thus, the total number of regular polygons is 7470.
#
# \boxed{7470}
# Extracted: 15...
# ---
# Q: Let \( f(n) = \sum_{r=1}^{n} (-1)^r \binom{n}{r}(n-r)^n \). Find the number of trailing zeroes in th...
# Expected: , and the last digit of \( 2021! \) is 0 (for \( n \geq 5 \)). Thus, \( 2021^{2021} - 2021! \) ends with \( 1 - 0 = 1 \), confirming no trailing zeroes.
#
# The number of trailing zeroes is 0.
#
# \boxed{0}
# Extracted: <think>
#
# First, observe that for \( n \geq 1 \), t...
# ---
# Q: Two savings plans are compared. Plan 1: Deposit $D at the start of each year for 10 years into an ac...
# Expected: 10633.03
# Extracted: $26,540.29...
# ---
# Q: A trader observes a spot rate of 1.25 USD/GBP. The 1-year risk-free rate in the US is 4% and in the ...
# Expected: 22400
# Extracted: In the Americas, to exploit the mispricing, we'd b...
# ---
# Q: Several drugstores received a shipment of 10 bottles, each containing 1000 pills. One of the bottles...
# Expected: ottle 1 is heavy.
# - If \(D / 10 = 2\), bottle 2 is heavy.
# - ...
# - If \(D / 10 = 10\), bottle 10 is heavy.
#
# This process guarantees identification of the heavy bottle with a single weighing.
#
# \boxed{1}
# Extracted: <think>
# Let's denote the good pills as 'G' weighin...
# ---
# Q: Evaluate the sum \( \sum_{n=1}^{\infty} \frac{(-1)^{n-1}}{\binom{2n}{n}n^3} \)....
# Expected: he sum is approximately 0.480822762, and \(\frac{2}{5} \zeta(3) \approx 0.4808227612638376\), with the difference attributed to truncation error in numerical computation.
#
# \boxed{\dfrac{2}{5}\zeta(3)}
# Extracted: <think>
#
# To evaluate the given sum, \( \sum_{n=1}^...
# ---
# Q: Given that \(x\vec{IA} + y\vec{IB} + z\vec{IC} = \vec{0}\), find the values of \(x\), \(y\), and \(z...
# Expected:  AB\), or in standard notation, \(x = a\), \(y = b\), \(z = c\), where \(a\), \(b\), \(c\) are the side lengths opposite vertices \(A\), \(B\), \(C\) respectively.
#
# \[
# \boxed{x = BC,\ y = AC,\ z = AB}
# Extracted: <think>
# To start, let's examine the relationship b...
# ---
# Q: Find the locus of $M$ when $ab = 1$, and $b$ varies with $0 < b \leq 1$. Provide the Cartesian equat...
# Expected: -axis as it approaches the origin, with \(x \geq y\) throughout.
#
# The locus is traced as \(b\) varies from 1 to \(0^+\), with \(a = \frac{1}{b}\) varying accordingly.
#
# \boxed{(x^{2} + y^{2})^{2} = xy}
# Extracted: Considering $ab=1$, the Cartesian equation would b...
# ---
# Q: A sequence $x_k$ represents a cumulative rate defined by the recurrence $x_0 = 0$ and $x_{k} = x_{k-...
# Expected: 41658
# Extracted: <think>
# We are given the recurrence $x_k = x_{k-1}...
# ---
# Q: A motorcycle and a car start from rest at the same point. The motorcycle accelerates at 3 m/s² for 1...
# Expected: 400 m
# Extracted: <think>
# Let's denote the time the motorcycle accel...
# ---
# Q: A triangle $ABC$ is divided into three equal figures by straight lines which arc parallel to the sid...
# Expected: e total length is \(a\).
#
# Thus, the parts into which \(AB\) is divided are as given.
#
# \[
# \boxed{\dfrac{a\left(3-\sqrt{6}\right)}{3},\ \dfrac{a\left(\sqrt{6}-\sqrt{3}\right)}{3},\ \dfrac{a\sqrt{3}}{3}}
# Extracted: <think>
# Let's consider the parallel lines that div...
# ---
# Q: Find all real values of \( m \) such that the inequality \( mx^2 + 2(m-1)x + m^2 > 0 \) holds for al...
# Expected: x > 2 \) (with equality at \( x = 2 \), but the strict inequality holds for \( x > 2 \)).
#
# Thus, the solution is all \( m \) such that \( m \geq 2\sqrt{5} - 4 \).
#
# \[
# \boxed{m \geqslant 2\sqrt{5} - 4}
# Extracted: \(m > 1\) and \(n < 4\)...
# ---
# Q: Find the volume of the solid bounded above by the paraboloid \( z = 9 - x^2 - y^2 \) and below by th...
# Expected: {\pi/2} 14  d\theta = 14 \left[ \theta \right]_{-\pi/2}^{\pi/2} = 14 \left( \frac{\pi}{2} - \left(-\frac{\pi}{2}\right) \right) = 14 \cdot \pi = 14\pi
# \]
#
# Thus, the volume is \(14\pi\).
#
# \boxed{14\pi}
# Extracted: <think>
#
# To solve this problem, we first need to e...
# ---
# Q: Find all functions \( f: \mathbb{Z}^+ \rightarrow \mathbb{Z}^+ \) such that \( f(m) + f(n) \mid (m+n...
# Expected: k \) (e.g., \( k = 1, 2, 3, 4 \)) and general analysis confirm that only the identity function works for all \( k \geq 1 \).
#
# Thus, the solution is unique and independent of \( k \).
#
# \boxed{f(n) = n}
# Extracted: <think>
#
# Let's analyze the problem statement. The ...
# ---
# Q: Find the value of the sum ${\sum_{k=1}^{n-1} \frac{1}{\sin ^ 2 \left(\frac{k\pi}{2n}\right)}}$ for $...
# Expected: c^2(3\pi/8) = (4 + 2\sqrt{2}) + 2 + (4 - 2\sqrt{2}) = 10\), and \(\frac{2(4^2 - 1)}{3} = \frac{2 \cdot 15}{3} = 10\).
#
# The formula holds for all \(n \geq 2\).
#
# \boxed{\dfrac{2\left(n^{2}-1\right)}{3}}
# Extracted: $\sum \limits_{k = 1}^{n  -  1}  1  =  \boxed{n - ...
# ---
# Q: Simplify the following expressions: $\frac{1}{2}\left(\sqrt {x^2+a}+\frac{x^2}{\sqrt {x^2+a}}\right)...
# Expected:  + a}{\sqrt{x^2 + a}} = (x^2 + a)^1 \cdot (x^2 + a)^{-1/2} = (x^2 + a)^{1/2} = \sqrt{x^2 + a}.
# \]
#
# The simplified expression is \(\sqrt{x^2 + a}\), valid for \(x^2 + a > 0\).
#
# \boxed{\sqrt{x^{2} + a}}
# Extracted: $$\boxed{1}$$...
# ---
# Q: Find all functions \( f: \mathbb{Q} \to \mathbb{R} \) such that for all \( x, y \in \mathbb{Q} \):
# \...
# Expected: nals. The recurrence and functional equation constrain the function to this form, and it is consistent across the rationals.
#
# Thus, the solution is \(f(x) = 2^{-x} - x\).
#
# \[
# \boxed{f(x) = 2^{-x} - x}
# Extracted: <think>
# To approach this problem, the first thing ...
# ---
# Q: Given a regular quadrangular pyramid $SABCD$. A plane is drawn through the midpoints of the edges $A...
# Expected: ontains vertices \(B\), \(C\), and \(D\). The volume of each polyhedron is \(\frac{1}{6} a^2 h\).
#
# Thus, the volumes of the two parts are equal, and the ratio of their volumes is \(1:1\).
#
# \boxed{1:1}
# Extracted: <think>
#
# To begin,  consider a vertical plane $xyz...
# ---
# Q: For which values of the parameter $a$ are the systems of equations $$\left\{\begin{array}{lll} \sin ...
# Expected: \pi \neq 0\)) and are not solutions to the second system. Thus, the solution sets differ.
#
# Therefore, the systems are equivalent if and only if \(a < \frac{\pi^2}{2}\).
#
# \boxed{a < \dfrac{\pi^{2}}{2}}
# Extracted: <think>
# First, consider the system of equations
# $$...
# ---
# Q: A regular hexagon with side length 6 is inscribed in a circle. From each vertex of the hexagon, a pe...
# Expected: 81√3
# Extracted: <think>
#
# Let's analyze the problem step by step:
#
# ...
# ---
# Q: In square \(ABCD\) with side length 3, point \(X\) is located on diagonal \(AC\) such that \(AX > XC...
# Expected: 36\sqrt{3} \approx 62.35382907252\), and \(90 - 62.35382907252 = 27.64617092748\). Since \(27 < 27.64617092748 < 28\),
# \[
# \lfloor 90 - 36\sqrt{3} \rfloor = 27.
# \]
#
# Thus, the value is 27.
#
# \boxed{27}
# Extracted: <think>
# Given square ABCD with side length 3, and ...
# ---
# Q: Let \(ABCD\) be a square. Let \(E\) be on the segment \(BC\) and \(F\) be on the segment \(DE\) such...
# Expected: } - \sqrt{2}}{4}.
# \]
# This is \(\cos 75^\circ\), so \(\theta = 75^\circ\).
#
# Verification using the tangent formula or angle sum in triangle \(DFA\) confirms \(\angle DFA = 75^\circ\).
#
# \boxed{75^\circ}
# Extracted: $45^\circ$...
# ---
# Q: Five cards with the number 1 and four cards with the number 2 are placed in a box. You randomly sele...
# Expected: {21}.
# \]
#
# The fraction \(\frac{10}{21}\) is in simplest form, as 10 and 21 have no common factors other than 1.
#
# Thus, the probability that the sum is odd is \(\frac{10}{21}\).
#
# \boxed{\dfrac{10}{21}}
# Extracted: <think>
# Since there are five cards with the number...
# ---
# Q: Solve the following equations, first reducing them to algebraic equations with respect to one trigon...
# Expected: ously.
#
# Thus, the general solution is given by the expressions above for integers \(k\).
#
# \boxed{x = \dfrac{\pi}{2} + k\pi \quad \text{or} \quad x = \pm \dfrac{\pi}{3} + 2k\pi, \quad k \in \mathbb{Z}}
# Extracted: <think>
# We are given the equation $
#
# 6\cos^2 x+\co...
# ---
# Q: In rectangle ABCD with AB = 8 and BC = 6, a point P is chosen uniformly at random inside the rectang...
# Expected: 2
# Extracted: <think>
# To approach this problem, we will first de...
# ---
# Q: Find \( f^{(20)}(2) \) for the function \( f(x) = \frac{x^4}{x^2 + 2x - 3} \)....
# Expected: c{5^{21} - 81}{5^{21}} = \frac{20! (5^{21} - 81)}{4 \cdot 5^{21}}. \]
#
# The expression is simplified, and no further reduction is necessary.
#
# \boxed{\dfrac{20!\left(5^{21}-81\right)}{4\cdot5^{21}}}
# Extracted: <think>
# To find the 20th derivative of the functio...
# ---
# Q: Let \( P(x) = x^2 + ax + b \) where \( a, b \in \mathbb{Z} \). For any integer \( n \), find all int...
# Expected: and they are generally distinct.
#
# Thus, for any integer \( n \), the integers \( m \) are given by the above formulas.
#
# \boxed{m = n^{2} + (a+1)n + b \quad \text{or} \quad m = -n^{2} - (a+1)n - a - b}
# Extracted: $$m = n^2 + an + b$$...
# ---
# Q: Given an infinite sheet of square ruled paper with an $m \times n$ rectangle $(m, n > 1)$ filled wit...
# Expected: blem, the smallest number is 2, as the \(2 \times 2\) case is handled separately but the problem likely expects the general case.
#
# Thus, the smallest number of pieces that can be left is 2.
#
# \boxed{2}
# Extracted: <think>
#
# We are dealing with pieces jumping over e...
# ---
# Q: A train has to cover 840 km in a specified time. At the half-distance point it was held up for half ...
# Expected:  hours,
# - Delay: 0.5 hours,
# - Time for second half: \(\frac{420}{40+2} = \frac{420}{42} = 10\) hours,
# Total: \(10.5 + 0.5 + 10 = 21\) hours.
#
# Thus, the train spent 21 hours en route.
#
# \boxed{21}
# Extracted: <think>
# Let's break down the problem step by step:...
# ---
# Q: A $8 \times 7$ piece of chocolate is made of 56 congruent square cells. Kevin selects a random cell ...
# Expected:  \times \left( \sum_{x=1}^{8} x \right) \times \left( \sum_{y=1}^{7} y \right) = \frac{1}{56} \times 36 \times 28 = \frac{1008}{56} = 18.
# \]
#
# All methods confirm the expected number is 18.
#
# \boxed{18}
# Extracted: <think>
#
# Since the chocolate is made of 56 congrue...
# ---
# Q: Find all real constants $\lambda$ such that there exists a triple of real numbers $(a,b,c)$, not all...
# Expected: \cdot 0\)
#   - \(|-1 - 0| = 1 = (-1) \cdot (-1)\)
#   - \(|0 - (-1)| = 1 = (-1) \cdot (-1)\)
#
# No other real values of \(\lambda\) satisfy the system for any non-zero triple \((a, b, c)\).
#
# \boxed{-1,0,1}
# Extracted: The complete solution set for $\lambda$ is $\lambd...
# ---
# Q: Solve the inequality
# \[ \dfrac{2x^{2}-5x-2}{3x-x^{2}-7} \geq 1 \]...
# Expected: expression is less than 1 (e.g., at \(x = 0\), it is \(\frac{2}{7} < 1\); at \(x = 2\), it is \(0.8 < 1\)).
#
# Thus, the solution is \(1 \leq x \leq \frac{5}{3}\).
#
# \[
# \boxed{1 \leq x \leq \dfrac{5}{3}}
# Extracted: <think>
#
# To solve the inequality, we first need to...
# ---
# Q: The Pentasect counts in base five and considers numbers containing a 2 in their base five representa...
# Expected: negative for \(n > 254\) due to the decreasing density of good numbers and long sequences of evil numbers, preventing it from returning to zero.
#
# Thus, the largest balanced number is 254.
#
# \boxed{254}
# Extracted: <think>
# We first consider how the numbers in base ...
# ---
# Q: Let $\tau$ be a circle with center $O$. Distinct points $A$, $B$, and $C$ are on $\tau$ such that $\...
# Expected: e possible measures of $\angle ACB$ are $30^\circ$ and $150^\circ$. The sum of these values is $30^\circ + 150^\circ = 180^\circ$.
#
# No other values of $\angle ACB$ satisfy the conditions.
#
# \boxed{180}
# Extracted: <think>
#
# Let $M$ and $N$ be the midpoints of $\ove...
# ---
# Q: Let \(ABC\) be a triangle with \(AB = 5\), \(BC = 7\), and \(CA = 8\). Let \(D\), \(E\), \(F\) be th...
# Expected: pi \cdot \frac{147}{144} = \pi \cdot \frac{49}{48}.
# \]
# The fraction \(\frac{49}{48}\) is in simplest form, as 49 and 48 are coprime.
#
# Thus, the area is \(\frac{49\pi}{48}\).
#
# \boxed{\dfrac{49\pi}{48}}
# Extracted: <think>
#
# To find the area of the circle that passe...
# ---
# Q: Find the number of points on the curve $\frac{1}{x} + \frac{1}{y} = \frac{1}{2004}$ whose coordinate...
# Expected:  + 1) = 5 \times 3 \times 3 = 45.
# \]
#
# Therefore, there are 45 ordered pairs \((x, y)\) of positive integers satisfying the equation. Each pair corresponds to a distinct point on the curve.
#
# \boxed{45}
# Extracted: <think>
# We are given the equation $\frac{1}{x} + \...
# ---
# Q: Find all continuous functions \( f: \mathbb{R} \to [0, 8] \) such that \( f(x^2 + y^2) = f(x^2 - y^2...
# Expected:  continuous and maps to \(\{0\} \subseteq [0, 8]\).
#
# No other continuous functions satisfy the conditions, as any non-zero \( f \) would be unbounded or violate the range constraint.
#
# \boxed{f(x) = 0}
# Extracted: <think>
# Let's consider the given functional equati...
# ---
# Q: Evaluate the limit \( \lim_{x \rightarrow 0^+} \left(\frac{1}{x}\right)^{\frac{1}{x}} \cdot x^{x^x} ...
# Expected: ox 1.049 \times 10^{2997}\).
# - At \(x = 0.0001\), \(L \approx 1.0085 \times 10^{39996}\).
#
# The value of \(L\) increases without bound as \(x \to 0^+\).
#
# Thus, the limit is \(+\infty\).
#
# \boxed{\infty}
# Extracted: <think>
#
# To evaluate the given limit, we'll break ...
# ---
# Q: An integer k is chosen uniformly at random from the set {1, 2, 3, ..., 110}. What is the expected va...
# Expected: 5
# Extracted: <think>
#
# To find the expected value of the remaind...
# ---
# Q: What is the sum of the roots of the equation \((2 - x)^{2012} - x^{2012} = 0\)?...
# Expected: \frac{4024 \times 2011}{-4024} = 2011.
# \]
#
# This result holds for the exponent \(2012\), and the sum includes all roots, real and complex, as per standard polynomial root sum conventions.
#
# \boxed{2011}
# Extracted: <think>
# We can rewrite this equation as:
# \((2 - x)...
# ---
# Q: Solve the following equations: $2^{1+2\cos 5x}+16^{\sin ^2(5x/2)}=9$....
# Expected: . All solutions satisfy the original equation.
#
# Thus, the general solution is \(x = \frac{2k\pi}{15}\) for all integers \(k\).
#
# \[
# \boxed{x = \dfrac{2k\pi}{15} \quad \text{for} \quad k \in \mathbb{Z}}
# Extracted: <div style="background-color: #f0f0f0">
#
# ## Think
# ...
# ---
# Q: A sphere of radius 5 cm contains a smaller, concentric sphere of radius 2 cm. A point is chosen unif...
# Expected: 13.28
# Extracted: The expected score is the sum of the product of ea...
# ---
# Q: An airplane was in flight from $A$ to $B$ in a straight line. Due to a head wind, after a certain ti...
# Expected: v(t_1 - t_2)}}
# \]
#
# This expression assumes \(t_1 > t_2\) (since reducing speed later results in less lateness) and \(60d > v(t_1 - t_2)\) to ensure \(s > v\).
#
# \boxed{\dfrac{60dv}{60d - v(t_1 - t_2)}}
# Extracted: <think>
# Let's assume that the original speed of th...
# ---
# Q: How many 7-digit even numbers less than 3,000,000 can be formed using all the digits (1, 2, 2, 3, 5,...
# Expected: 60\) (since there are two identical 5's).
#
# Summing the cases:
# \(60 + 30 + 60 + 60 = 210\).
#
# Thus, there are 210 such 7-digit even numbers less than 3,000,000 using all the given digits.
#
# \boxed{210}
# Extracted: <think>
#
# To form an even 7-digit number, we must h...

# %%
# Cell 9: Save Model
import os

# Option 1: Save locally
output_path = "llama-3.2-8b-reasoning-unsloth-HICRA-v1"
model.save_pretrained(output_path)
tokenizer.save_pretrained(output_path)
print(f"✅ Model saved to {output_path}")

# Option 2: Push to HuggingFace Hub (uncomment to use)
# repo_name = "DataImaginations/Llama-1B-Reasoning-v1"
# hf_token = os.getenv('HF_TOKEN')
# 
# print(f"⏳ Pushing to {repo_name}...")
# model.push_to_hub_merged(
#     repo_name,
#     tokenizer,
#     save_method="merged_16bit",
#     token=hf_token
# )
# print("✅ Model pushed to Hub!")

# %%
# Cell: Merge LoRA adapters and save for evaluation
from unsloth import FastLanguageModel

# Load the adapter model
model, tokenizer = FastLanguageModel.from_pretrained(
    "llama-8b-reasoning-unsloth-HICRA-v1",
    max_seq_length=1024,
    load_in_4bit=True,
)

# Merge and save in 16-bit
print("⏳ Merging adapters...")
model.save_pretrained_merged(
    "llama-3.2-8b-reasoning-merged-v1",  # New path for merged model
    tokenizer,
    save_method="merged_16bit",  # Full precision merged weights
)
print("✅ Merged model saved!")

# %% [markdown]
# ## Test the Trained Model

# %%
# Cell 10: Test Inference
from unsloth import FastLanguageModel

# Put model in inference mode
FastLanguageModel.for_inference(model)

# Test question
test_question = "A loan is repaid with 20 equal annual payments. The interest portion of the 16th payment is 400 and the interest portion of the 11th payment is 600. Find the interest portion of the 1st payment."

messages = [
    {"role": "system", "content": SYSTEM_PROMPT.strip()},
    {"role": "user", "content": test_question}
]

inputs = tokenizer.apply_chat_template(
    messages,
    tokenize=True,
    add_generation_prompt=True,
    return_tensors="pt"
).to(model.device)

outputs = model.generate(
    input_ids=inputs,
    max_new_tokens=256,
    temperature=0.7,
)

response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print("Question:", test_question)
print("\nResponse:")
print(response)

# %% [markdown]
# # Bench for unsloth_HICRA

# %%
import lm_eval
from lm_eval.models.huggingface import HFLM

# 1. Load your local model
# If you just saved your model to "llama-1b-reasoning-final", point to that folder.
print("⏳ Loading model for evaluation...")

# We wrap the model in the Harness's HFLM wrapper
# 'pretrained' can be a local path OR a Hub ID (e.g., "david-barnes/my-model")
llm = HFLM(
    pretrained="llama-8b-reasoning-merged-v1",  # Use the merged model
    batch_size=1,
    trust_remote_code=True,
    dtype="bfloat16"
)

# 2. Define the tasks you want
# These key names correspond to the harness registry.
# Note: "minerva_math" is often split by subject (algebra, etc), 
# so we usually run the main "math" group or specific subtasks.
task_list = [
    "aime24",          # AIME 2024
    "minerva_math",    # Minerva Math (covers multiple subjects)
    # "math_500",        # The 'easy' 500 questions from MATH
    "leaderboard_gpqa_main",   # leaderboard_math_hard      
]

# 3. Run the Eval
print(f"🚀 Running evaluation on: {task_list}...")
results = lm_eval.simple_evaluate(
    model=llm,
    tasks=task_list,
    num_fewshot=0,        # Reasoning models often prefer 0-shot (Instruction)
    limit=None,           # Set to e.g., 50 to test quickly before full run!
    log_samples=True,    # Set True if you want to see exactly what it got wrong
)

# 4. Print a Pretty Table
from lm_eval.utils import make_table
print(make_table(results))

# 5. Save detailed results to JSON (Crucial for your blog!)
import json
with open("llama_8b_unsloth_HICRA_v1_benchmark_results.json", "w") as f:
    json.dump(results, f, indent=2)

# %% [markdown]
# # Soft VRAM clear

# %%
import torch
import gc

# 1. Delete the Python variables holding the model
# (Wrap in try/except so it doesn't crash if they are already gone)
try:
    del model
    del tokenizer
    del trainer
except NameError:
    print("Variables already deleted or not defined.")

# 2. Python Garbage Collection (Clears CPU RAM)
gc.collect()

# 3. PyTorch Cache Clearing (The most important step for VRAM)
torch.cuda.empty_cache()

# Verify: Print current memory usage
print(f"GPU Memory Allocated: {torch.cuda.memory_allocated() / 1024**3:.2f} GB")
print(f"GPU Memory Reserved:  {torch.cuda.memory_reserved() / 1024**3:.2f} GB")
